# %%
import pandas as pd
import numpy as np

import altair as alt
import json

# %% [markdown]
# ### LOAD DATA AND PREPARE

# %%
data = pd.read_csv('data/goods-value-2000-2020.csv')

# %%
data.head()
# Out:
#        Commodity  Commodity Code  Partner  Partner Code Partner ISO  \
# 0  Animals; live               1  Denmark           208         DNK
# 1  Animals; live               1  Denmark           208         DNK
# 2  Animals; live               1  Estonia           233         EST
# 3  Animals; live               1  Estonia           233         EST
# 4  Animals; live               1  Finland           246         FIN
#
#              Reporter  Reporter Code Reporter ISO Trade Flow  \
# 0  Russian Federation            643          RUS     Import
# 1  Russian Federation            643          RUS     Export
# 2  Russian Federation            643          RUS     Import
# 3  Russian Federation            643          RUS     Export
# 4  Russian Federation            643          RUS     Import
#
#    Trade Value (US$)  Year
# 0           21603580  2017
# 1                100  2017
# 2            1373584  2017
# 3               1674  2017
# 4            1084495  2017

# %%
totals = data.groupby(['Partner', 'Year', 'Trade Flow']).agg({
    'Trade Value (US$)': 'sum'
}).reset_index()

# %%
totals.head()
# Out:
#    Partner  Year Trade Flow  Trade Value (US$)
# 0  Algeria  2000     Export           91969291
# 1  Algeria  2000     Import              30595
# 2  Algeria  2001     Export          129432534
# 3  Algeria  2001     Import              56490
# 4  Algeria  2002     Export          137641022

# %%
data_pct = data.merge(
    totals,
    on = ['Partner', 'Year', 'Trade Flow'],
    how = 'inner',
    suffixes = ["", "_total"]
)

data_pct.loc[:, 'Trade Value Pct'] = (data_pct['Trade Value (US$)'] / data_pct['Trade Value (US$)_total'] * 100).round(2)

# %%
data_pct.head()
# Out:
#                                            Commodity  Commodity Code  Partner  \
# 0                                      Animals; live               1  Denmark
# 1                         Meat and edible meat offal               2  Denmark
# 2  Dairy produce; birds' eggs; natural honey; edi...               4  Denmark
# 3  Animal originated products; not elsewhere spec...               5  Denmark
# 4  Trees and other plants, live; bulbs, roots and...               6  Denmark
#
#    Partner Code Partner ISO            Reporter  Reporter Code Reporter ISO  \
# 0           208         DNK  Russian Federation            643          RUS
# 1           208         DNK  Russian Federation            643          RUS
# 2           208         DNK  Russian Federation            643          RUS
# 3           208         DNK  Russian Federation            643          RUS
# 4           208         DNK  Russian Federation            643          RUS
#
#   Trade Flow  Trade Value (US$)  Year  Trade Value (US$)_total  \
# 0     Import           21603580  2017               1086635679
# 1     Import            1601932  2017               1086635679
# 2     Import             607834  2017               1086635679
# 3     Import            2246384  2017               1086635679
# 4     Import           16790015  2017               1086635679
#
#    Trade Value Pct
# 0             1.99
# 1             0.15
# 2             0.06
# 3             0.21
# 4             1.55

# %% [markdown]
# ### TOP-10 GOODS CATEGORIES FOR EACH COUNTRY

# %%
def top_goods(group, top = 10):
    subgroup = group.sort_values(by='Trade Value (US$)', ascending=False)
    
    subtop = top if top else len(subgroup)
    
    return subgroup.loc[
        :,
        ['Commodity', 'Commodity Code', 'Trade Value Pct', 'Trade Value (US$)']
    ].head(subtop).reset_index()

# %%
top10_goods_data = data_pct.loc[
    :
].groupby([
    'Partner', 'Year', 'Trade Flow'
]).apply(
    top_goods,
    top = 10
)

goods_data = data_pct.loc[
    :
].groupby([
    'Partner', 'Year', 'Trade Flow'
]).apply(
    top_goods,
    top = None
)

# %%
top10_goods_data.head()
# Out:
#                            index  \
# Partner Year Trade Flow
# Algeria 2000 Export     0  57512
#                         1  57550
#                         2  57548
#                         3  57549
#                         4  57541
#
#                                                                    Commodity  \
# Partner Year Trade Flow
# Algeria 2000 Export     0  Animal,vegetable fats and oils, cleavage produ...
#                         1               Vehicles other than railway, tramway
#                         2          Nuclear reactors, boilers, machinery, etc
#                         3                   Electrical, electronic equipment
#                         4                                     Iron and steel
#
#                            Commodity Code  Trade Value Pct  Trade Value (US$)
# Partner Year Trade Flow
# Algeria 2000 Export     0              15            22.09           20314021
#                         1              87            21.48           19758587
#                         2              84            12.84           11805594
#                         3              85             8.00            7355364
#                         4              72             7.25            6670264

# %%
top10_goods_data = top10_goods_data.reset_index().rename(columns={'level_3': 'Rank'})
top10_goods_data.loc[:, 'Rank'] += 1
top10_goods_data = top10_goods_data.drop('index', axis=1)

# %%
goods_data = goods_data.reset_index().rename(columns={'level_3': 'Rank'})
goods_data.loc[:, 'Rank'] += 1
goods_data = goods_data.drop('index', axis=1)

# %%
top10_goods_data.loc[
    top10_goods_data.Partner == 'China'
].sort_values(by=['Year', 'Trade Flow']).head(15)
# Out:
#      Partner  Year Trade Flow  Rank  \
# 4346   China  2000     Export     1
# 4347   China  2000     Export     2
# 4348   China  2000     Export     3
# 4349   China  2000     Export     4
# 4350   China  2000     Export     5
# 4351   China  2000     Export     6
# 4352   China  2000     Export     7
# 4353   China  2000     Export     8
# 4354   China  2000     Export     9
# 4355   China  2000     Export    10
# 4356   China  2000     Import     1
# 4357   China  2000     Import     2
# 4358   China  2000     Import     3
# 4359   China  2000     Import     4
# 4360   China  2000     Import     5
#
#                                               Commodity  Commodity Code  \
# 4346                                     Iron and steel              72
# 4347                     Aluminium and articles thereof              76
# 4348         Ships, boats and other floating structures              89
# 4349    Mineral fuels, oils, distillation products, etc              27
# 4350           Wood and articles of wood, wood charcoal              44
# 4351                      Plastics and articles thereof              39
# 4352                                  Organic chemicals              29
# 4353                                        Fertilizers              31
# 4354  Pulp of wood, fibrous cellulosic material, was...              47
# 4355            Printed books, newspapers, pictures etc              49
# 4356                                  Organic chemicals              29
# 4357    Mineral fuels, oils, distillation products, etc              27
# 4358                     Toys, games, sports requisites              95
# 4359                Miscellaneous manufactured articles              96
# 4360          Nuclear reactors, boilers, machinery, etc              84
#
#       Trade Value Pct  Trade Value (US$)
# 4346            20.09          883651550
# 4347            11.86          521513212
# 4348             8.49          373534106
# 4349             7.97          350452163
# 4350             7.83          344473940
# 4351             5.47          240692881
# 4352             5.46          239940403
# 4353             5.35          235255398
# 4354             4.52          198984787
# 4355             3.53          155142710
# 4356             7.63           72388890
# 4357             6.14           58281501
# 4358             5.94           56390756
# 4359             5.92           56131199
# 4360             5.09           48339443

# %%
goods_data.loc[
    goods_data.Partner == 'China'
].sort_values(by=['Year', 'Trade Flow']).head(15)
# Out:
#       Partner  Year Trade Flow  Rank  \
# 27037   China  2000     Export     1
# 27038   China  2000     Export     2
# 27039   China  2000     Export     3
# 27040   China  2000     Export     4
# 27041   China  2000     Export     5
# 27042   China  2000     Export     6
# 27043   China  2000     Export     7
# 27044   China  2000     Export     8
# 27045   China  2000     Export     9
# 27046   China  2000     Export    10
# 27047   China  2000     Export    11
# 27048   China  2000     Export    12
# 27049   China  2000     Export    13
# 27050   China  2000     Export    14
# 27051   China  2000     Export    15
#
#                                                Commodity  Commodity Code  \
# 27037                                     Iron and steel              72
# 27038                     Aluminium and articles thereof              76
# 27039         Ships, boats and other floating structures              89
# 27040    Mineral fuels, oils, distillation products, etc              27
# 27041           Wood and articles of wood, wood charcoal              44
# 27042                      Plastics and articles thereof              39
# 27043                                  Organic chemicals              29
# 27044                                        Fertilizers              31
# 27045  Pulp of wood, fibrous cellulosic material, was...              47
# 27046            Printed books, newspapers, pictures etc              49
# 27047               Vehicles other than railway, tramway              87
# 27048  Arms and ammunition, parts and accessories the...              93
# 27049          Nuclear reactors, boilers, machinery, etc              84
# 27050  Paper & paperboard, articles of pulp, paper an...              48
# 27051                          Articles of iron or steel              73
#
#        Trade Value Pct  Trade Value (US$)
# 27037            20.09          883651550
# 27038            11.86          521513212
# 27039             8.49          373534106
# 27040             7.97          350452163
# 27041             7.83          344473940
# 27042             5.47          240692881
# 27043             5.46          239940403
# 27044             5.35          235255398
# 27045             4.52          198984787
# 27046             3.53          155142710
# 27047             3.19          140209853
# 27048             2.79          122622573
# 27049             2.50          110160290
# 27050             1.48           65154959
# 27051             1.26           55230501

# %% [markdown]
# ### TODO: UNIFY COMMODITIES NAMES

# %% [markdown]
# ### EDA

# %%
def subset_top_goods(top_goods_data, country, trade_flow, years = [2000, 2020]):
    subdata = top_goods_data.loc[
        (top_goods_data.Partner == country) & \
        (top_goods_data.Year >= years[0]) & (top_goods_data.Year <= years[1]) &\
        (top_goods_data['Trade Flow'] == trade_flow)
    ]
    
    return subdata

# %%
def get_top_goods(top_goods_data, country, trade_flow, years = [2000, 2020], top = 10):
    
    def group_pct(tx):
        years = list(tx['Year'])
        pct_vals = list(tx['Trade Value Pct'])
        
        return [{'year': year, 'pct': pct} for year, pct in zip(years, pct_vals)]
        
    
    subdata = subset_top_goods(top_goods_data, country, trade_flow, years = years)
    
    group = subdata.groupby('Commodity Code')
    
    result = pd.DataFrame({
        'commodity': group.apply(lambda tx: tx['Commodity'].iloc[0]),
        'flow': trade_flow,
        'total': group.apply(lambda tx: tx['Trade Value (US$)'].sum()),
        'records': group.apply(group_pct),
    }).sort_values(by='total', ascending=False).head(top)
    
    return result.reset_index().rename(
        columns={
            'Commodity Code': 'commodity_code'
        }
    ).to_dict(orient='records')

# %%
get_top_goods(top10_goods_data, 'Algeria', 'Export', [2010, 2020], top = 3)
# Out:
# [{'commodity_code': 99,
#   'commodity': 'Commodities not specified according to kind',
#   'flow': 'Export',
#   'total': 12399439746,
#   'records': [{'year': 2016, 'pct': 64.81},
#    {'year': 2017, 'pct': 57.01},
#    {'year': 2018, 'pct': 66.78},
#    {'year': 2019, 'pct': 53.28},
#    {'year': 2020, 'pct': 68.83}]},
#  {'commodity_code': 93,
#   'commodity': 'Arms and ammunition; parts and accessories thereof',
#   'flow': 'Export',
#   'total': 3140357961,
#   'records': [{'year': 2010, 'pct': 28.97},
#    {'year': 2011, 'pct': 46.33},
#    {'year': 2012, 'pct': 24.99},
#    {'year': 2013, 'pct': 31.84},
#    {'year': 2014, 'pct': 1.19},
#    {'year': 2015, 'pct': 24.16},
#    {'year': 2016, 'pct': 8.43},
#    {'year': 2017, 'pct': 0.55},
#    {'year': 2018, 'pct': 1.37},
#    {'year': 2019, 'pct': 1.85}]},
#  {'commodity_code': 87,
#   'commodity': 'Vehicles other than railway or tramway rolling-stock, and parts and accessories thereof',
#   'flow': 'Export',
#   'total': 2861082577,
#   'records': [{'year': 2010, 'pct': 9.17},
#    {'year': 2011, 'pct': 6.94},
#    {'year': 2012, 'pct': 34.22},
#    {'year': 2013, 'pct': 21.51},
#    {'year': 2015, 'pct': 10.48},
#    {'year': 2016, 'pct': 2.19},
#    {'year': 2017, 'pct': 8.14},
#    {'year': 2018, 'pct': 5.21},
#    {'year': 2019, 'pct': 7.46},
#    {'year': 2020, 'pct': 7.73}]}]

# %%
get_top_goods(goods_data, 'Algeria', 'Export', [2010, 2020], top = 3)
# Out:
# [{'commodity_code': 99,
#   'commodity': 'Commodities not specified according to kind',
#   'flow': 'Export',
#   'total': 12399439746,
#   'records': [{'year': 2016, 'pct': 64.81},
#    {'year': 2017, 'pct': 57.01},
#    {'year': 2018, 'pct': 66.78},
#    {'year': 2019, 'pct': 53.28},
#    {'year': 2020, 'pct': 68.83}]},
#  {'commodity_code': 93,
#   'commodity': 'Arms and ammunition; parts and accessories thereof',
#   'flow': 'Export',
#   'total': 3140357961,
#   'records': [{'year': 2010, 'pct': 28.97},
#    {'year': 2011, 'pct': 46.33},
#    {'year': 2012, 'pct': 24.99},
#    {'year': 2013, 'pct': 31.84},
#    {'year': 2014, 'pct': 1.19},
#    {'year': 2015, 'pct': 24.16},
#    {'year': 2016, 'pct': 8.43},
#    {'year': 2017, 'pct': 0.55},
#    {'year': 2018, 'pct': 1.37},
#    {'year': 2019, 'pct': 1.85}]},
#  {'commodity_code': 87,
#   'commodity': 'Vehicles other than railway or tramway rolling-stock, and parts and accessories thereof',
#   'flow': 'Export',
#   'total': 2861243832,
#   'records': [{'year': 2010, 'pct': 9.17},
#    {'year': 2011, 'pct': 6.94},
#    {'year': 2012, 'pct': 34.22},
#    {'year': 2013, 'pct': 21.51},
#    {'year': 2014, 'pct': 0.02},
#    {'year': 2015, 'pct': 10.48},
#    {'year': 2016, 'pct': 2.19},
#    {'year': 2017, 'pct': 8.14},
#    {'year': 2018, 'pct': 5.21},
#    {'year': 2019, 'pct': 7.46},
#    {'year': 2020, 'pct': 7.73}]}]

# %% [markdown]
# #### AREA CHART FACET

# %%
def country_goods_facet(top_goods_data, country, trade_flow, years, top):

    country_data = get_top_goods(top_goods_data, country, trade_flow, years, top = top)

    chart_df = pd.DataFrame([])
    for commodity in country_data:
        df = pd.DataFrame(commodity['records'])
        df.loc[:, 'commodity'] = commodity['commodity']
        df.loc[:, 'commodity_code'] = commodity['commodity_code']

        chart_df = pd.concat([
            chart_df,
            df
        ])

    chart = alt.Chart(chart_df).mark_area().encode(
        alt.X('year:O'),
        alt.Y('pct', scale=alt.Scale(domain=[0, 100])),
        color = alt.Color('commodity:N')
    ).properties(
        width=250,
        height=55
    ).facet(
        facet='commodity_code',
        columns = 1
    )
    
    return chart

# %%
alt.hconcat(
    country_goods_facet(top10_goods_data, "China", "Import", years=[2000, 2020], top=5),
    country_goods_facet(top10_goods_data, "China", "Export", years=[2000, 2020], top=5)
)
# Out:
# alt.HConcatChart(...)

# %%
alt.hconcat(
    country_goods_facet(goods_data, "China", "Import", years=[2000, 2020], top=5),
    country_goods_facet(goods_data, "China", "Export", years=[2000, 2020], top=5)
)
# Out:
# alt.HConcatChart(...)

# %%
country = "Germany"
alt.hconcat(
    country_goods_facet(goods_data, country, "Import", years=[2000, 2020], top=5),
    country_goods_facet(goods_data, country, "Export", years=[2000, 2020], top=5)
)
# Out:
# alt.HConcatChart(...)

# %%
country = "Belarus"
alt.hconcat(
    country_goods_facet(goods_data, country, "Import", years=[2000, 2020], top=5),
    country_goods_facet(goods_data, country, "Export", years=[2000, 2020], top=5)
)
# Out:
# alt.HConcatChart(...)

# %%
country = "Netherlands"
alt.hconcat(
    country_goods_facet(goods_data, country, "Import", years=[2000, 2020], top=5),
    country_goods_facet(goods_data, country, "Export", years=[2000, 2020], top=5)
)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ### SAVE DATA

# %%
len(goods_data)
# Out:
# 176767

# %%
goods_data.head()
# Out:
#    Partner  Year Trade Flow  Rank  \
# 0  Algeria  2000     Export     1
# 1  Algeria  2000     Export     2
# 2  Algeria  2000     Export     3
# 3  Algeria  2000     Export     4
# 4  Algeria  2000     Export     5
#
#                                            Commodity  Commodity Code  \
# 0  Animal,vegetable fats and oils, cleavage produ...              15
# 1               Vehicles other than railway, tramway              87
# 2          Nuclear reactors, boilers, machinery, etc              84
# 3                   Electrical, electronic equipment              85
# 4                                     Iron and steel              72
#
#    Trade Value Pct  Trade Value (US$)
# 0            22.09           20314021
# 1            21.48           19758587
# 2            12.84           11805594
# 3             8.00            7355364
# 4             7.25            6670264

# %%
def goods_recs(country, flow):
    
    recs = goods_data.loc[
        (goods_data.Partner == country) & (goods_data['Trade Flow'] == flow),
        ['Year', 'Commodity Code', 'Trade Value Pct', 'Trade Value (US$)']
    ].rename(columns={
        'Year': 'year',
        'Commodity Code': 'ccode',
        'Trade Value Pct': 'pct',
        'Trade Value (US$)': 'value'
    }).to_dict(orient='records')
    
    return recs

# %%
commodities_import_export_data = {}

for country in np.unique(goods_data.Partner):
    if country != 'Other Asia, nes':
        commodities_import_export_data[country] = {}
        for flow in ['Import', 'Export']:
            commodities_import_export_data[country][flow] = goods_recs(country, flow)

# %%
with open('data/commodities_import_export_data.json', 'w') as f:
    json.dump(commodities_import_export_data, f)

# %% [markdown]
# #### SAVE AS SEPARATE FILES

# %%
# Partner - code map
partner_codes = data_pct.groupby('Partner').agg({
    'Partner Code': 'first'
}).to_dict()['Partner Code']

# %%
with open('data/commodities_flow/partner_codes.json', 'w') as f:
    json.dump(partner_codes, f)

# %%
for country in np.unique(goods_data.Partner):
    if country != 'Other Asia, nes':
        commodities_flow = {}
        country_code = partner_codes[country]
        
        for flow in ['Import', 'Export']:
            commodities_flow[flow] = goods_recs(country, flow)
        
        filename = 'data/commodities_flow/{country_code}.json'.format(country_code=country_code)
        with open(filename, 'w') as f:
            json.dump(commodities_flow, f)
